# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
match1 = pd.read_csv("/content/drive/MyDrive/deliveries.csv")
score = pd.read_csv("/content/drive/MyDrive/matches.csv")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
score.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match1.max()
# Out:
# <ipython-input-13-aa9a6def6d33>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   match1.max()
# match_id                       11415
# inning                             5
# batting_team     Sunrisers Hyderabad
# bowling_team     Sunrisers Hyderabad
# over                              20
# ball                               9
# batsman                       Z Khan
# non_striker                   Z Khan
# bowler                        Z Khan
# is_super_over                      1
# wide_runs                          5
# bye_runs                           4
# legbye_runs                        5
# noball_runs                        5
# penalty_runs                       5
# batsman_runs                       7
# extra_runs                         7
# ...

# %%
score.max()
# Out:
# <ipython-input-14-e9daab44ce87>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   score.max()
# id                              11415
# season                           2019
# date                         31/03/19
# team1             Sunrisers Hyderabad
# team2             Sunrisers Hyderabad
# toss_winner       Sunrisers Hyderabad
# toss_decision                   field
# result                            tie
# dl_applied                          1
# win_by_runs                       146
# win_by_wickets                     10
# venue                Wankhede Stadium
# dtype: object

# %%
match1.min()
# Out:
# <ipython-input-15-ce6a1d876ce2>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   match1.min()
# match_id                           1
# inning                             1
# batting_team     Chennai Super Kings
# bowling_team     Chennai Super Kings
# over                               1
# ball                               1
# batsman               A Ashish Reddy
# non_striker           A Ashish Reddy
# bowler                A Ashish Reddy
# is_super_over                      0
# wide_runs                          0
# bye_runs                           0
# legbye_runs                        0
# noball_runs                        0
# penalty_runs                       0
# batsman_runs                       0
# extra_runs                         0
# ...

# %%
score.min()
# Out:
# <ipython-input-16-311c689e809d>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   score.min()
# id                                  1
# season                           2008
# date                         01/04/19
# team1             Chennai Super Kings
# team2             Chennai Super Kings
# toss_winner       Chennai Super Kings
# toss_decision                     bat
# result                      no result
# dl_applied                          0
# win_by_runs                         0
# win_by_wickets                      0
# venue                ACA-VDCA Stadium
# dtype: object

# %%
match1.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
score.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
match1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match1.tail()
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
score.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
match1.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
score.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
match1.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='season', data=score)
plt.show()

# %%
plt.figure(figsize=(12,6))
data = score.winner.value_counts()
sns.barplot(y = data.index, x = data, orient='h')
plt.show()

# %%
top_players = score.player_of_match.value_counts()[:10]
#sns.barplot(x="day", y="total_bill", data=df)
fig, ax = plt.subplots(figsize=(15,8))
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match Winners")
top_players.plot.bar()
sns.barplot(x = top_players.index, y = top_players, orient='v', palette="Blues");
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='venue', data=score)
plt.xticks(rotation='vertical')
plt.show()

# %%
# Number of matches played by each team:

temp_df = pd.melt(score, id_vars=['id','season'], value_vars=['team1', 'team2'])

plt.figure(figsize=(12,6))
sns.countplot(x='value', data=temp_df)
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='winner', data=score)
plt.xticks(rotation=90)
plt.show()

# %%
score.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
plt.figure(figsize=(30,6))
sns.countplot(x='city', data=score)
plt.show()

# %%
score["winner"].value_counts().nlargest(n=1).values[0]
# Out:
# 109

# %%
# select all cases where age is greater than 28 and grade is 'A'
da2=score[score['season'] == 2011]
da2
# Out:
#       id  season       city        date                        team1  \
# 234  235    2011    Chennai  2011-04-08          Chennai Super Kings
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 236  237    2011      Kochi  2011-04-09         Kochi Tuskers Kerala
# 237  238    2011      Delhi  2011-04-10             Delhi Daredevils
# 238  239    2011     Mumbai  2011-04-10              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 302  303    2011    Kolkata  2011-05-22        Kolkata Knight Riders
# 303  304    2011     Mumbai  2011-05-24  Royal Challengers Bangalore
# 304  305    2011     Mumbai  2011-05-25        Kolkata Knight Riders
# 305  306    2011    Chennai  2011-05-27  Royal Challengers Bangalore
# 306  307    2011    Chennai  2011-05-28          Chennai Super Kings
#
#                            team2           toss_winner toss_decision  result  \
# ...

# %%
da1=score[score['winner'] == 'Mumbai Indians']
da1
# Out:
#         id  season       city        date                        team1  \
# 6        7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 9       10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 11      12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 15      16    2017     Mumbai  2017-04-16                Gujarat Lions
# 21      22    2017     Indore  2017-04-20              Kings XI Punjab
# ..     ...     ...        ...         ...                          ...
# 739  11335    2019    Chennai    26/04/19               Mumbai Indians
# 746  11342    2019     Mumbai    02/05/19               Mumbai Indians
# 751  11347    2019     Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019    Chennai    07/05/19          Chennai Super Kings
# 755  11415    2019  Hyderabad    12/05/19               Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# ...

# %%
da2[da2['winner']=='Mumbai Indians']
# Out:
#       id  season       city        date                        team1  \
# 237  238    2011      Delhi  2011-04-10             Delhi Daredevils
# 241  242    2011  Bangalore  2011-04-12  Royal Challengers Bangalore
# 253  254    2011     Mumbai  2011-04-20                Pune Warriors
# 256  257    2011     Mumbai  2011-04-22               Mumbai Indians
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 272  273    2011     Mumbai  2011-05-02               Mumbai Indians
# 276  277    2011     Mumbai  2011-05-04               Mumbai Indians
# 281  282    2011     Mumbai  2011-05-07               Mumbai Indians
# 302  303    2011    Kolkata  2011-05-22        Kolkata Knight Riders
# 304  305    2011     Mumbai  2011-05-25        Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  result  \
# 237       Mumbai Indians     Delhi Daredevils           bat  normal
# 241       Mumbai Indians       Mumbai Indians         field  normal
# ...

# %%
# select all cases where age is greater than 28 and grade is 'A'
score.loc[(score['season'] == 2011) & (score['winner'] == Mumbai Indians)]
# Out:
#   File "<ipython-input-57-3c9107a18860>", line 2
#     score.loc[(score['season'] == 2011) & (score['winner'] == Mumbai Indians)]
#                                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
da2['winner'].value_counts()['Mumbai Indians']
# Out:
# 10

# %%
da3=score[score['season'] == 2019]

# %%
da3
# Out:
#         id  season           city      date                        team1  \
# 696  11137    2019        Chennai  23/03/19  Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19          Sunrisers Hyderabad
# 698  11139    2019         Mumbai  24/03/19               Delhi Capitals
# 699  11140    2019         Jaipur  25/03/19              Kings XI Punjab
# 700  11141    2019          Delhi  26/03/19               Delhi Capitals
# 701  11142    2019        Kolkata  27/03/19        Kolkata Knight Riders
# 702  11143    2019      Bengaluru  28/03/19               Mumbai Indians
# 703  11144    2019      Hyderabad  29/03/19             Rajasthan Royals
# 704  11145    2019         Mohali  30/03/19               Mumbai Indians
# 705  11146    2019          Delhi  30/03/19        Kolkata Knight Riders
# 706  11147    2019      Hyderabad  31/03/19          Sunrisers Hyderabad
# 707  11148    2019        Chennai  31/03/19          Chennai Super Kings
# ...

# %%
max(da3['win_by_runs'])
# Out:
# 118

# %%
da4=da3['win_by_runs']

# %%
da4
# Out:
# 696      0
# 697      0
# 698     37
# 699     14
# 700      0
# 701     28
# 702      6
# 703      0
# 704      0
# 705      0
# 706    118
# 707      8
# 708     14
# 709      0
# 710     37
# 711      0
# 712      0
# 713     22
# 714     40
# 715      0
# 716      0
# 717      0
# 718      0
# 719      0
# 720      0
# 721      0
# 722      0
# 723      0
# 724      0
# 725     39
# 726      0
# 727     12
# 728      0
# 729     40
# 730     10
# 731      0
# 732      0
# 733      0
# 734      1
# 735      0
# 736      0
# 737     17
# 738      0
# 739     46
# 740      0
# 741     16
# 742     34
# 743     45
# 744      0
# 745     80
# 746      0
# 747      0
# 748      0
# 749      0
# 750      0
# 751      0
# 752      0
# 753      0
# 754      0
# 755      1
# Name: win_by_runs, dtype: int64

# %%
max(da3['player_of_match'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-fec4849b843d> in <cell line: 1>()
# ----> 1 max(da3['player_of_match'])
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
max(da3['win_by_runs'])
# Out:
# 118

# %%
da3['player_of_match']

# %%
da2['win_by_wickets'].value_counts()['Kolkata Knight Riders']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Kolkata Knight Riders'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-3a5ae9690946> in <cell line: 1>()
# ...

# %%
max(score['win_by_wickets'])
# Out:
# 10

# %%
match1[(match1['batsman']==V Kohli) & (match1['bowler']== JJ Bumrah)]
# Out:
#   File "<ipython-input-84-a76a73242526>", line 1
#     match1[(match1['batsman']==V Kohli) & (match1['bowler']== JJ Bumrah)]
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# select all cases where age is greater than 28 and grade is 'A'
df5=match1.loc[(match1['batsman'] == 'V Kohli') & (df5['bowler'] == 'JJ Bumrah')]

# %%
df5
# Out:
#         match_id  inning                 batting_team    bowling_team  over  \
# 2633          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2634          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2635          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2637          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2638          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# ...          ...     ...                          ...             ...   ...
# 166347     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166348     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166349     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166406     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
# 166408     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
#
# ...

# %%
max(df5['batsman_runs'])
# Out:
# 6
